# %%
import pandas as pd

# Load the data
routes = pd.read_csv('data/synthetic/routes.csv')
fleet_info = pd.read_csv('data/synthetic/fleet_info.csv')
weather = pd.read_csv('data/synthetic/weather.csv')

print('=== CATEGORICAL FEATURE VALUES ===')
print()

# From routes.csv
print('driver_profile values:')
print(list(routes['driver_profile'].unique()))
print(f'Count: {routes["driver_profile"].nunique()}')
print()

# From fleet_info.csv
print('model values:')
print(list(fleet_info['model'].unique()))
print(f'Count: {fleet_info["model"].nunique()}')
print()

print('driving_style values:')
print(list(fleet_info['driving_style'].unique()))
print(f'Count: {fleet_info["driving_style"].nunique()}')
print()

print('driver_personality values:')
print(list(fleet_info['driver_personality'].unique()))
print(f'Count: {fleet_info["driver_personality"].nunique()}')
print()

# From weather.csv
print('weather_season values:')
print(list(weather['season'].unique()))
print(f'Count: {weather["season"].nunique()}')
print()

# Trip type will be created during feature engineering
print('trip_type values (created during feature engineering):')
print('["local", "highway", "city"]')
print('Count: 3')
print()

print('=== TIME FEATURES CURRENTLY USED ===')
print('1. hour (0-23) - extracted from date')
print('2. day_of_week (0-6) - Monday=0, Sunday=6')  
print('3. month (1-12) - extracted from date')
print('4. is_weekend (0/1) - derived from day_of_week')
print('5. is_rush_hour (0/1) - derived from hour (7-9 AM, 5-7 PM)')
print()

print('=== RECOMMENDATIONS ===')
print('Time features to keep (choose 1-2):')
print('- KEEP: hour (most predictive for consumption patterns)')
print('- KEEP: is_weekend (captures weekday vs weekend patterns)')
print('- REMOVE: day_of_week (redundant with is_weekend)')
print('- REMOVE: month (seasonality already captured by weather_season)')
print('- REMOVE: is_rush_hour (correlated with hour)')
